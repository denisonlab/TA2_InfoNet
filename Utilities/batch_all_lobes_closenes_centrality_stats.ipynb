# %% [markdown]
# Examples on how to run Group_Closeness_Stats_vslow.py

# %%
import os
import subprocess
this_folder = '/usr3/graduate/jtszhu/TA2/InfoNet/'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'temporal', '0.65', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9042780 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 20 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'temporal', '0.5', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9044388 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 20 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'occipital', '0.5', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9048756 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 20 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'occipital', '0.65', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049311 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 20 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'occipital', '0.75', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049314 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 20 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'occipital', '0.85', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049315 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 20 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'occipital', '0.95', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049328 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'temporal', '0.75', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9044938 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'temporal', '0.85', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9049319 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'temporal', '0.9', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9049320 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'temporal', '0.95', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9049326 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', 'temporal', '0.99', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9049341 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', 'parietal', '0.5', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049318 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', 'parietal', '0.65', '1000', 'False')
                              ,shell=True))
# Out:
# b'Your job 9048766 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', 'parietal', '0.75', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049331 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', 'parietal', '0.85', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049332 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', 'parietal', '0.8', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049349 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 24 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', 'parietal', '0.95', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049333 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
for plot_lobe in ['occipital', 'parietal', 'temporal', 'frontal', 'cingulate', 'insula']:    
    print(subprocess.check_output("qsub " + "-pe omp 28 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', plot_lobe, '0.95', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049433 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049434 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049435 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049436 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049437 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049438 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
for plot_lobe in ['occipital', 'parietal', 'temporal', 'frontal', 'cingulate', 'insula']:    
    print(subprocess.check_output("qsub " + "-pe omp 28 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', plot_lobe, '0.85', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049593 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049594 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049595 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049596 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049597 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049598 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
for plot_lobe in ['occipital', 'parietal', 'temporal', 'frontal', 'cingulate', 'insula']:    
    print(subprocess.check_output("qsub " + "-pe omp 28 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T1_attend', 'T1_unattend', plot_lobe, '0.99', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9061536 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9061537 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9061538 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9061539 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9061540 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9061541 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
for plot_lobe in ['occipital', 'parietal', 'temporal', 'frontal', 'cingulate', 'insula']:    
    print(subprocess.check_output("qsub " + "-pe omp 28 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', plot_lobe, '0.85', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9049439 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049440 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049441 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049442 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049443 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9049444 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                          + this_folder + 
                          "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                          ('T2_attend', 'T2_unattend', 'None', '0.85', '1000', 'one_side')
                          ,shell=True))
# Out:
# b'Your job 9049573 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                          + this_folder + 
                          "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                          ('T1_attend', 'T1_unattend', 'None', '0.85', '1000', 'one_side')
                          ,shell=True))
# Out:
# b'Your job 9049615 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                          + this_folder + 
                          "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                          ('T1_attend', 'T1_unattend', 'None', '0.95', '1000', 'one_side')
                          ,shell=True))
# Out:
# b'Your job 9049616 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                          + this_folder + 
                          "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                          ('T1_attend', 'T1_unattend', 'None', '0.99', '1000', 'one_side')
                          ,shell=True))
# Out:
# b'Your job 9068879 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                          + this_folder + 
                          "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                          ('T1_attend', 'T1_unattend', 'None', '0.75', '1000', 'one_side')
                          ,shell=True))
# Out:
# b'Your job 9068858 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                          + this_folder + 
                          "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                          ('T1_attend', 'T1_unattend', 'None', '0.6', '1000', 'one_side')
                          ,shell=True))
# Out:
# b'Your job 9894051 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                          + this_folder + 
                          "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                          ('T1_attend', 'T1_unattend', 'None', '0.6', '1000', 'two_side')
                          ,shell=True))
# Out:
# b'Your job 9894052 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
for plot_lobe in ['occipital', 'parietal', 'temporal', 'frontal', 'cingulate', 'insula']:    
    print(subprocess.check_output("qsub " + "-pe omp 28 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', plot_lobe, '0.99', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9558504 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9558505 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9558506 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9558507 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9558508 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
# b'Your job 9558509 ("Group_Closeness_Stats_vslow.py") has been submitted\n'

# %%
print(subprocess.check_output("qsub " + "-pe omp 28 " 
                              + this_folder + 
                              "Group_Closeness_Stats_vslow.py %s %s %s %s %s %s"%
                              ('T2_attend', 'T2_unattend', 'parietal', '0.99', '1000', 'one_side')
                              ,shell=True))
# Out:
# b'Your job 9564965 ("Group_Closeness_Stats_vslow.py") has been submitted\n'
